# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
pwd = os.getcwd()
df_emp = pd.read_csv(pwd+'/HR_Data.csv')
df_emp
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df_emp.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
corr = df_emp.corr()
fig, ax = plt.subplots(figsize=(20,20))
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %%
df_emp.hist(bins=30, figsize=(20,20));

# %%
df_emp['Attrition'] = df_emp['Attrition'].apply(lambda x:1 if x=='Yes' else 0)
df_emp['OverTime'] = df_emp['OverTime'].apply(lambda x:1 if x=='Yes' else 0)
df_emp['Over18'] = df_emp['Over18'].apply(lambda x:1 if x=='Y' else 0)

# %%
df_emp.hist(bins=30, figsize=(20,20));

# %%
df_emp.drop(['EmployeeCount', 'StandardHours', 'Over18', 'EmployeeNumber'], axis=1, inplace=True)

# %%
df_emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   int64
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   object
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobRole                   1470 non-null   object
# ...

# %%
df_resigned = df_emp[df_emp['Attrition']==1]
df_stayed = df_emp[df_emp['Attrition']==0]
print('Total = ', len(df_emp))
print('Resigned Employees = ', len(df_resigned))
print('% People that Resigned = ', len(df_resigned)/len(df_emp)*100,'%')
print('% People that Stayed = ', len(df_stayed)/len(df_emp)*100,'%')
# Out:
# Total =  1470
# Resigned Employees =  237
# % People that Resigned =  16.122448979591837 %
# % People that Stayed =  83.87755102040816 %

# %%
df_resigned.describe()
# Out:
#               Age  Attrition    DailyRate  DistanceFromHome   Education  \
# count  237.000000      237.0   237.000000        237.000000  237.000000
# mean    33.607595        1.0   750.362869         10.632911    2.839662
# std      9.689350        0.0   401.899519          8.452525    1.008244
# min     18.000000        1.0   103.000000          1.000000    1.000000
# 25%     28.000000        1.0   408.000000          3.000000    2.000000
# 50%     32.000000        1.0   699.000000          9.000000    3.000000
# 75%     39.000000        1.0  1092.000000         17.000000    4.000000
# max     58.000000        1.0  1496.000000         29.000000    5.000000
#
#        EnvironmentSatisfaction  HourlyRate  JobInvolvement    JobLevel  \
# count               237.000000  237.000000      237.000000  237.000000
# mean                  2.464135   65.573840        2.518987    1.637131
# std                   1.169791   20.099958        0.773405    0.940594
# ...

# %%
df_stayed.describe()
# Out:
#                Age  Attrition    DailyRate  DistanceFromHome    Education  \
# count  1233.000000     1233.0  1233.000000       1233.000000  1233.000000
# mean     37.561233        0.0   812.504461          8.915653     2.927007
# std       8.888360        0.0   403.208379          8.012633     1.027002
# min      18.000000        0.0   102.000000          1.000000     1.000000
# 25%      31.000000        0.0   477.000000          2.000000     2.000000
# 50%      36.000000        0.0   817.000000          7.000000     3.000000
# 75%      43.000000        0.0  1176.000000         13.000000     4.000000
# max      60.000000        0.0  1499.000000         29.000000     5.000000
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              1233.000000  1233.000000     1233.000000  1233.000000
# mean                  2.771290    65.952149        2.770479     2.145985
# std                   1.071132    20.380754        0.692050     1.117933
# ...

# %%
plt.figure(figsize=(25,12))
sns.countplot(x='Age', data=df_resigned)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
plt.figure(figsize=(25,12))
sns.countplot(x='Age', data=df_stayed)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
plt.figure(figsize=(25,12))
sns.countplot(x='Age', data=df_emp, hue='Attrition')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
plt.figure(figsize=(20,20))
plt.subplot(4,1,1)
sns.countplot(x='JobRole', hue='Attrition', data=df_emp)
plt.subplot(4,1,2)
sns.countplot(x='MaritalStatus', hue='Attrition', data=df_emp)
plt.subplot(4,1,3)
sns.countplot(x='JobInvolvement', hue='Attrition', data=df_emp)
plt.subplot(4,1,4)
sns.countplot(x='JobLevel', hue='Attrition', data=df_emp)
# Out:
# <AxesSubplot:xlabel='JobLevel', ylabel='count'>

# %%
plt.figure(figsize=(12,7))
sns.kdeplot(df_resigned['DistanceFromHome'], label='Employees that Resigned', shade=True, color='r')
sns.kdeplot(df_stayed['DistanceFromHome'], label='Employees that Resigned', shade=True, color='b');

# %%
plt.figure(figsize=(12,7))
sns.kdeplot(df_resigned['MonthlyIncome'], label='Employees that Resigned', shade=True, color='r')
sns.kdeplot(df_stayed['MonthlyIncome'], label='Employees that Resigned', shade=True, color='b');

# %%
plt.figure(figsize=(12,7))
sns.kdeplot(df_resigned['DailyRate'], label='Employees that Resigned', shade=True, color='r')
sns.kdeplot(df_stayed['DailyRate'], label='Employees that Resigned', shade=True, color='b');
